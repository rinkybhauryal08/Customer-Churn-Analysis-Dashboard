# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
df = pd.read_csv("Customer_Churn_Analysis.csv")

# %%
df.to_csv("Customer_Churn_Analysis.csv",index=False)

# %%
df.head()
# Out:
#   Customer_ID Contract_ID Payment_ID  Gender  Age  Tenure_Months  \
# 0   CUST00001    CON00001   PAY00001  Female   29             58
# 1   CUST00002    CON00002   PAY00002  Female   56             69
# 2   CUST00003    CON00003   PAY00003  Female   27             39
# 3   CUST00004    CON00004   PAY00004    Male   24             38
# 4   CUST00005    CON00005   PAY00005    Male   73             44
#
#    Monthly_Charges  Total_Charges Internet_Service  Customer_Support_Calls  \
# 0            95.71        5551.18      Fiber Optic                       6
# 1            99.46        6862.74      Fiber Optic                       2
# 2            27.99        1091.61              NaN                       3
# 3            48.59        1846.42      Fiber Optic                       1
# 4            63.18        2779.92            Cable                       6
#
#   Senior_Citizen Partner Dependents Churn
# 0             No     Yes         No   Yes
# ...

# %% [raw]
# df.tail()

# %%
df.shape
# Out:
# (8000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_ID             8000 non-null   object
#  1   Contract_ID             8000 non-null   object
#  2   Payment_ID              8000 non-null   object
#  3   Gender                  8000 non-null   object
#  4   Age                     8000 non-null   int64
#  5   Tenure_Months           8000 non-null   int64
#  6   Monthly_Charges         8000 non-null   float64
#  7   Total_Charges           8000 non-null   float64
#  8   Internet_Service        5951 non-null   object
#  9   Customer_Support_Calls  8000 non-null   int64
#  10  Senior_Citizen          8000 non-null   object
#  11  Partner                 8000 non-null   object
#  12  Dependents              8000 non-null   object
#  13  Churn                   8000 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age  Tenure_Months  Monthly_Charges  Total_Charges  \
# count  8000.000000    8000.000000      8000.000000    8000.000000
# mean     47.846375      36.333500        62.704521    2294.740500
# std      18.115368      20.617988        24.721418    1677.019644
# min      18.000000       1.000000        24.990000      25.120000
# 25%      31.000000      21.000000        45.560000    1048.410000
# 50%      51.000000      36.000000        59.970000    1905.180000
# 75%      64.000000      52.000000        81.792500    3167.672500
# max      77.000000      72.000000       104.980000    7529.760000
#
#        Customer_Support_Calls
# count             8000.000000
# mean                 3.684375
# std                  2.607509
# min                  0.000000
# 25%                  1.000000
# 50%                  4.000000
# 75%                  6.000000
# max                  9.000000

# %%
df.describe(include="object")
# Out:
#        Customer_ID Contract_ID Payment_ID  Gender Internet_Service  \
# count         8000        8000       8000    8000             5951
# unique        8000        8000       8000       2                3
# top      CUST00001    CON00001   PAY00001  Female            Cable
# freq             1           1          1    4196             2241
#
#        Senior_Citizen Partner Dependents Churn
# count            8000    8000       8000  8000
# unique              2       2          2     2
# top                No      No        Yes   Yes
# freq             4525    4346       4300  4145

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Contract_ID', 'Payment_ID', 'Gender', 'Age',
#        'Tenure_Months', 'Monthly_Charges', 'Total_Charges', 'Internet_Service',
#        'Customer_Support_Calls', 'Senior_Citizen', 'Partner', 'Dependents',
#        'Churn'],
#       dtype='object')

# %%
df = df.drop(columns=["Unnamed: 0"],axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = df.drop(columns=["Unnamed: 0"],axis = 1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df.dtypes
# Out:
# Customer_ID                object
# Contract_ID                object
# Payment_ID                 object
# Gender                     object
# Age                         int64
# Tenure_Months               int64
# Monthly_Charges           float64
# Total_Charges             float64
# Internet_Service           object
# Customer_Support_Calls      int64
# Senior_Citizen             object
# Partner                    object
# Dependents                 object
# Churn                      object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Customer_ID                  0
# Contract_ID                  0
# Payment_ID                   0
# Gender                       0
# Age                          0
# Tenure_Months                0
# Monthly_Charges              0
# Total_Charges                0
# Internet_Service          2049
# Customer_Support_Calls       0
# Senior_Citizen               0
# Partner                      0
# Dependents                   0
# Churn                        0
# dtype: int64

# %%
df["Internet_Service"] = df["Internet_Service"].fillna(df["Internet_Service"].mode()[0])

# %%
df["Internet_Service"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Internet_Service"].value_counts()
# Out:
# Internet_Service
# Cable          4290
# Fiber Optic    2070
# DSL            1640
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# Customer_ID               8000
# Contract_ID               8000
# Payment_ID                8000
# Gender                       2
# Age                         60
# Tenure_Months               72
# Monthly_Charges           3973
# Total_Charges             7698
# Internet_Service             3
# Customer_Support_Calls      10
# Senior_Citizen               2
# Partner                      2
# Dependents                   2
# Churn                        2
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Female    4196
# Male      3804
# Name: count, dtype: int64

# %%
df["Internet_Service"].value_counts()
# Out:
# Internet_Service
# Cable          4290
# Fiber Optic    2070
# DSL            1640
# Name: count, dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# Churn
# Yes    4145
# No     3855
# Name: count, dtype: int64

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['Age', 'Tenure_Months', 'Monthly_Charges', 'Total_Charges',
#        'Customer_Support_Calls'],
#       dtype='object')

# %%
df['Churn'].value_counts(normalize=True)*100  ##churn percentage
# Out:
# Churn
# Yes    51.8125
# No     48.1875
# Name: proportion, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_ID             8000 non-null   object
#  1   Contract_ID             8000 non-null   object
#  2   Payment_ID              8000 non-null   object
#  3   Gender                  8000 non-null   object
#  4   Age                     8000 non-null   int64
#  5   Tenure_Months           8000 non-null   int64
#  6   Monthly_Charges         8000 non-null   float64
#  7   Total_Charges           8000 non-null   float64
#  8   Internet_Service        5951 non-null   object
#  9   Customer_Support_Calls  8000 non-null   int64
#  10  Senior_Citizen          8000 non-null   object
#  11  Partner                 8000 non-null   object
#  12  Dependents              8000 non-null   object
#  13  Churn                   8000 non-null   object
# ...

# %%
df.head()
# Out:
#   Customer_ID Contract_ID Payment_ID  Gender  Age  Tenure_Months  \
# 0   CUST00001    CON00001   PAY00001  Female   29             58
# 1   CUST00002    CON00002   PAY00002  Female   56             69
# 2   CUST00003    CON00003   PAY00003  Female   27             39
# 3   CUST00004    CON00004   PAY00004    Male   24             38
# 4   CUST00005    CON00005   PAY00005    Male   73             44
#
#    Monthly_Charges  Total_Charges Internet_Service  Customer_Support_Calls  \
# 0            95.71        5551.18      Fiber Optic                       6
# 1            99.46        6862.74      Fiber Optic                       2
# 2            27.99        1091.61            Cable                       3
# 3            48.59        1846.42      Fiber Optic                       1
# 4            63.18        2779.92            Cable                       6
#
#   Senior_Citizen Partner Dependents Churn
# 0             No     Yes         No   Yes
# ...

# %%
df.to_csv("Cleaned_Customer_Churn_Analysis.csv", index = False)
